# %%
from urllib.request import urlopen
import json

response=urlopen('https://api.openf1.org/v1/pit?session_key=9896')
data=json.load(response)

# %%
print(data)
# Out:
# [{'date': '2025-10-05T12:25:48.079000+00:00', 'session_key': 9896, 'pit_duration': 24.61, 'meeting_key': 1270, 'driver_number': 22, 'lap_number': 13, 'lane_duration': 24.61, 'stop_duration': 2.1}, {'date': '2025-10-05T12:25:51.721000+00:00', 'session_key': 9896, 'pit_duration': 32.856, 'meeting_key': 1270, 'driver_number': 5, 'lap_number': 13, 'lane_duration': 32.856, 'stop_duration': 11.2}, {'date': '2025-10-05T12:27:18.400000+00:00', 'session_key': 9896, 'pit_duration': 24.04, 'meeting_key': 1270, 'driver_number': 43, 'lap_number': 14, 'lane_duration': 24.04, 'stop_duration': 2.7}, {'date': '2025-10-05T12:34:57.215000+00:00', 'session_key': 9896, 'pit_duration': 24.008, 'meeting_key': 1270, 'driver_number': 1, 'lap_number': 19, 'lane_duration': 24.008, 'stop_duration': 3.0}, {'date': '2025-10-05T12:37:03.329000+00:00', 'session_key': 9896, 'pit_duration': 23.827, 'meeting_key': 1270, 'driver_number': 6, 'lap_number': 20, 'lane_duration': 23.827, 'stop_duration': 2.4}, {'date': '202
# ...

# %%
import pandas as pd

data2=pd.DataFrame(data)

# %%
print(data2)
# Out:
#                                 date  session_key  pit_duration  meeting_key  \
# 0   2025-10-05T12:25:48.079000+00:00         9896        24.610         1270
# 1   2025-10-05T12:25:51.721000+00:00         9896        32.856         1270
# 2   2025-10-05T12:27:18.400000+00:00         9896        24.040         1270
# 3   2025-10-05T12:34:57.215000+00:00         9896        24.008         1270
# 4   2025-10-05T12:37:03.329000+00:00         9896        23.827         1270
# 5   2025-10-05T12:38:22.641000+00:00         9896        23.630         1270
# 6   2025-10-05T12:41:57.960000+00:00         9896        23.979         1270
# 7   2025-10-05T12:43:21.169000+00:00         9896        24.794         1270
# 8   2025-10-05T12:43:56.518000+00:00         9896        25.583         1270
# 9   2025-10-05T12:44:30.970000+00:00         9896        23.966         1270
# 10  2025-10-05T12:44:51.800000+00:00         9896        23.806         1270
# ...

# %%
print(type (data2))
print(data2.dtypes)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# date              object
# session_key        int64
# pit_duration     float64
# meeting_key        int64
# driver_number      int64
# lap_number         int64
# lane_duration    float64
# stop_duration    float64
# dtype: object
